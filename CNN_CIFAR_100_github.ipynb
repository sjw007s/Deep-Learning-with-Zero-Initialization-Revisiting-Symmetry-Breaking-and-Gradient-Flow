# %%
import torch
import csv
import numpy as np
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from torch import nn
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.cuda.set_device(0)

# %%
local_adress = "C:/Users/sjw00/OneDrive/Desktop/dataset/"

temp_list = list()
r=open(local_adress+'cifar-100-python/train_data_CIFAR_100.csv', 'r' )
reader=csv.reader(r)
for target in reader:
    temp_list.append(target)
training_data = np.array(temp_list).reshape((-1, 3, 32, 32)).astype(np.float32)
print(training_data.shape)
training_data = torch.from_numpy(training_data).to("cuda")

temp_list = list()
r=open(local_adress+'cifar-100-python/test_data_CIFAR_100.csv', 'r' )
reader=csv.reader(r)
for target in reader:
    temp_list.append(target)
test_data = np.array(temp_list).reshape((-1, 3, 32, 32)).astype(np.float32)
print(test_data.shape)
test_data = torch.from_numpy(test_data).to("cuda")
temp_array = np.identity(100)
temp_list = list()
r=open(local_adress+'cifar-100-python/train_target_fine_CIFAR_100.csv', 'r' )
reader=csv.reader(r)
for target in reader:
    
    temp_list.append(temp_array[int(target[0]),:])
    
training_target = np.array(temp_list).astype(np.float32)
print(training_target.shape)
training_target = torch.from_numpy(training_target).to("cuda")

temp_list = list()

r=open(local_adress+'cifar-100-python/test_target_fine_CIFAR_100.csv', 'r' )
reader=csv.reader(r)
for target in reader:
    
    temp_list.append(temp_array[int(target[0]),:])
    
test_target = np.array(temp_list).astype(np.float32)
print(test_target.shape)
test_target = torch.from_numpy(test_target).to("cuda")
# Out:
# (50000, 3, 32, 32)
# (10000, 3, 32, 32)
# (50000, 100)
# (10000, 100)

# %%
batch_size = 100
epochs = 200

# %%
training_dataset = TensorDataset(training_data, training_target)
test_dataset = TensorDataset(test_data, test_target)

training_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.layer_1 = nn.Conv2d(3,3,3,stride=1,padding=1)
        self.layer_2 = nn.Conv2d(3,3,3,stride=1,padding=1)
        self.layer_3 = nn.Conv2d(3,3,3,stride=1,padding=1)
        self.layer_4 = nn.Linear(3072,100)
        self.lrelu = nn.LeakyReLU()
        self.flatten = nn.Flatten()
        self.softmax = nn.Softmax(dim=1)
        
        torch.nn.init.zeros_(self.layer_1.weight)
        torch.nn.init.zeros_(self.layer_1.bias)
        torch.nn.init.zeros_(self.layer_2.weight)
        torch.nn.init.zeros_(self.layer_2.bias)
        torch.nn.init.zeros_(self.layer_3.weight)
        torch.nn.init.zeros_(self.layer_3.bias)
        torch.nn.init.zeros_(self.layer_4.weight)
        torch.nn.init.zeros_(self.layer_4.bias)
        
    def forward(self, x):
        x_1 = self.lrelu(self.layer_1(x)) + x
        x_1 = self.lrelu(self.layer_2(x_1)) + x_1
        x_1 = self.lrelu(self.layer_3(x_1)) + x_1
        x_1 = self.flatten(x_1)
        x_1 = self.layer_4(x_1)
        return x_1
# Out:
# Total number of parameters: 307552

# %%
def train(dataloader, model, loss_fn, optimizer, scaler):
    for batch, (X, y) in enumerate(dataloader):
        with torch.autocast(device_type='cuda', dtype=torch.bfloat16):
            pred = model(X)
            batch_loss_result = loss_fn(pred, y)
        optimizer.zero_grad()

        scaler.scale(batch_loss_result).backward() # Backpropagation: compute gradients
        scaler.step(optimizer) # Update model parameters using the optimizer
        scaler.update() # Update the gradient scaler

# %%
def test(dataloader, model):
    with torch.no_grad():
        accuracy_sum=0
        
        for _, (X, y) in enumerate(dataloader):
            with torch.autocast(device_type='cuda', dtype=torch.bfloat16):
                pred = model(X)
            accuracy_sum+= (torch.argmax(pred, dim=1) == torch.argmax(y,dim=1)).type(torch.float).sum().item()
            

        print("test_accuracy", accuracy_sum/10000)
    return accuracy_sum/10000

# %%
summary = list()
total_list = []
for i in range(20):
    model = CNN().to("cuda")
    loss_fn = nn.CrossEntropyLoss()
    scaler = torch.amp.GradScaler()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.95)
    accuracy = 0 
    epoch_list = []
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")
        train(training_dataloader, model, loss_fn, optimizer, scaler)
        accuracy_temp = test(test_dataloader, model)
        epoch_list.append(accuracy_temp)
        scheduler.step()
        if accuracy_temp > accuracy:
            accuracy = accuracy_temp
    total_list.append(epoch_list)
    summary.append(accuracy)
    print(summary)
with open("cifar-100_allzero.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerows(total_list)
print("Done!")
print(summary)
# Out:
# Epoch 1
# -------------------------------
# test_accuracy 0.0725
# Epoch 2
# -------------------------------
# test_accuracy 0.07
# Epoch 3
# -------------------------------
# test_accuracy 0.0608
# Epoch 4
# -------------------------------
# test_accuracy 0.0827
# Epoch 5
# -------------------------------
# test_accuracy 0.0877
# Epoch 6
# -------------------------------
# test_accuracy 0.0789
# Epoch 7
# -------------------------------
# test_accuracy 0.0881
# Epoch 8
# -------------------------------
# test_accuracy 0.0752
# Epoch 9
# -------------------------------
# test_accuracy 0.0751
# Epoch 10
# -------------------------------
# test_accuracy 0.0908
# Epoch 11
# -------------------------------
# test_accuracy 0.0923
# Epoch 12
# -------------------------------
# test_accuracy 0.0746
# Epoch 13
# -------------------------------
# test_accuracy 0.0756
# Epoch 14
# -------------------------------
# test_accuracy 0.0858
# Epoch 15
# -------------------------------
# test_accuracy 0.0885
# Epoch 16
# -------------------------------
# test_accuracy 0.0939
# Epoch 17
# -------------------------------
# test_accuracy 0.1028
# Epoch 18
# -------------------------------
# test_accuracy 0.0919
# Epoch 19
# -------------------------------
# test_accuracy 0.0901
# Epoch 20
# -------------------------------
# test_accuracy 0.0915
# Epoch 21
# -------------------------------
# test_accuracy 0.0846
# Epoch 22
# -------------------------------
# test_accuracy 0.0814
# Epoch 23
# -------------------------------
# test_accuracy 0.0877
# Epoch 24
# -------------------------------
# test_accuracy 0.0911
# Epoch 25
# -------------------------------
# test_accuracy 0.0902
# Epoch 26
# -------------------------------
# test_accuracy 0.1007
# Epoch 27
# -------------------------------
# test_accuracy 0.0988
# Epoch 28
# -------------------------------
# test_accuracy 0.1002
# Epoch 29
# -------------------------------
# test_accuracy 0.0907
# Epoch 30
# -------------------------------
# test_accuracy 0.0949
# Epoch 31
# -------------------------------
# test_accuracy 0.0961
# Epoch 32
# -------------------------------
# test_accuracy 0.0907
# Epoch 33
# -------------------------------
# test_accuracy 0.0981
# Epoch 34
# -------------------------------
# test_accuracy 0.1049
# Epoch 35
# -------------------------------
# test_accuracy 0.0913
# Epoch 36
# -------------------------------
# test_accuracy 0.0937
# Epoch 37
# -------------------------------
# test_accuracy 0.0942
# Epoch 38
# -------------------------------
# test_accuracy 0.1028
# Epoch 39
# -------------------------------
# test_accuracy 0.0992
# Epoch 40
# -------------------------------
# test_accuracy 0.0966
# Epoch 41
# -------------------------------
# test_accuracy 0.0945
# Epoch 42
# -------------------------------
# test_accuracy 0.0955
# Epoch 43
# -------------------------------
# test_accuracy 0.1
# Epoch 44
# -------------------------------
# test_accuracy 0.1051
# Epoch 45
# -------------------------------
# test_accuracy 0.0957
# Epoch 46
# -------------------------------
# test_accuracy 0.1051
# Epoch 47
# -------------------------------
# test_accuracy 0.1024
# Epoch 48
# -------------------------------
# test_accuracy 0.1024
# Epoch 49
# -------------------------------
# test_accuracy 0.1046
# Epoch 50
# -------------------------------
# test_accuracy 0.0971
# Epoch 51
# -------------------------------
# test_accuracy 0.0954
# Epoch 52
# -------------------------------
# test_accuracy 0.1017
# Epoch 53
# -------------------------------
# test_accuracy 0.1021
# Epoch 54
# -------------------------------
# test_accuracy 0.0992
# Epoch 55
# -------------------------------
# test_accuracy 0.0998
# Epoch 56
# -------------------------------
# test_accuracy 0.0892
# Epoch 57
# -------------------------------
# test_accuracy 0.0978
# Epoch 58
# -------------------------------
# test_accuracy 0.1065
# Epoch 59
# -------------------------------
# test_accuracy 0.0931
# Epoch 60
# -------------------------------
# test_accuracy 0.1087
# Epoch 61
# -------------------------------
# test_accuracy 0.0969
# Epoch 62
# -------------------------------
# test_accuracy 0.0968
# Epoch 63
# -------------------------------
# test_accuracy 0.0953
# Epoch 64
# -------------------------------
# test_accuracy 0.091
# Epoch 65
# -------------------------------
# test_accuracy 0.0956
# Epoch 66
# -------------------------------
# test_accuracy 0.0997
# Epoch 67
# -------------------------------
# test_accuracy 0.094
# Epoch 68
# -------------------------------
# test_accuracy 0.0989
# Epoch 69
# -------------------------------
# test_accuracy 0.0993
# Epoch 70
# -------------------------------
# test_accuracy 0.1016
# Epoch 71
# -------------------------------
# test_accuracy 0.0925
# Epoch 72
# -------------------------------
# test_accuracy 0.0947
# Epoch 73
# -------------------------------
# test_accuracy 0.1024
# Epoch 74
# -------------------------------
# test_accuracy 0.1033
# Epoch 75
# -------------------------------
# test_accuracy 0.1035
# Epoch 76
# -------------------------------
# test_accuracy 0.0914
# Epoch 77
# -------------------------------
# test_accuracy 0.0992
# Epoch 78
# -------------------------------
# test_accuracy 0.0983
# Epoch 79
# -------------------------------
# test_accuracy 0.0981
# Epoch 80
# -------------------------------
# test_accuracy 0.1018
# Epoch 81
# -------------------------------
# test_accuracy 0.0997
# Epoch 82
# -------------------------------
# test_accuracy 0.0979
# Epoch 83
# -------------------------------
# test_accuracy 0.1012
# Epoch 84
# -------------------------------
# test_accuracy 0.1007
# Epoch 85
# -------------------------------
# test_accuracy 0.0949
# Epoch 86
# -------------------------------
# test_accuracy 0.0985
# Epoch 87
# -------------------------------
# test_accuracy 0.096
# Epoch 88
# -------------------------------
# test_accuracy 0.0969
# Epoch 89
# -------------------------------
# test_accuracy 0.0975
# Epoch 90
# -------------------------------
# test_accuracy 0.0945
# Epoch 91
# -------------------------------
# test_accuracy 0.0985
# Epoch 92
# -------------------------------
# test_accuracy 0.0952
# Epoch 93
# -------------------------------
# test_accuracy 0.0968
# Epoch 94
# -------------------------------
# test_accuracy 0.0986
# Epoch 95
# -------------------------------
# test_accuracy 0.0963
# Epoch 96
# -------------------------------
# test_accuracy 0.0958
# Epoch 97
# -------------------------------
# test_accuracy 0.0955
# Epoch 98
# -------------------------------
# test_accuracy 0.0987
# Epoch 99
# -------------------------------
# test_accuracy 0.1008
# Epoch 100
# -------------------------------
# test_accuracy 0.0998
# Epoch 101
# -------------------------------
# test_accuracy 0.1008
# Epoch 102
# -------------------------------
# test_accuracy 0.0985
# Epoch 103
# -------------------------------
# test_accuracy 0.0986
# Epoch 104
# -------------------------------
# test_accuracy 0.1033
# Epoch 105
# -------------------------------
# test_accuracy 0.0963
# Epoch 106
# -------------------------------
# test_accuracy 0.0972
# Epoch 107
# -------------------------------
# test_accuracy 0.0977
# Epoch 108
# -------------------------------
# test_accuracy 0.1019
# Epoch 109
# -------------------------------
# test_accuracy 0.0986
# Epoch 110
# -------------------------------
# test_accuracy 0.0986
# Epoch 111
# -------------------------------
# test_accuracy 0.096
# Epoch 112
# -------------------------------
# test_accuracy 0.0968
# Epoch 113
# -------------------------------
# test_accuracy 0.0955
# Epoch 114
# -------------------------------
# test_accuracy 0.0981
# Epoch 115
# -------------------------------
# test_accuracy 0.0976
# Epoch 116
# -------------------------------
# test_accuracy 0.0982
# Epoch 117
# -------------------------------
# test_accuracy 0.0962
# Epoch 118
# -------------------------------
# test_accuracy 0.1011
# Epoch 119
# -------------------------------
# test_accuracy 0.094
# Epoch 120
# -------------------------------
# test_accuracy 0.0971
# Epoch 121
# -------------------------------
# test_accuracy 0.0982
# Epoch 122
# -------------------------------
# test_accuracy 0.0948
# Epoch 123
# -------------------------------
# test_accuracy 0.096
# Epoch 124
# -------------------------------
# test_accuracy 0.1005
# Epoch 125
# -------------------------------
# test_accuracy 0.0972
# Epoch 126
# -------------------------------
# test_accuracy 0.0939
# Epoch 127
# -------------------------------
# test_accuracy 0.0948
# Epoch 128
# -------------------------------
# test_accuracy 0.0938
# Epoch 129
# -------------------------------
# test_accuracy 0.0993
# Epoch 130
# -------------------------------
# test_accuracy 0.0961
# Epoch 131
# -------------------------------
# test_accuracy 0.0991
# Epoch 132
# -------------------------------
# test_accuracy 0.0973
# Epoch 133
# -------------------------------
# test_accuracy 0.0932
# Epoch 134
# -------------------------------
# test_accuracy 0.0928
# Epoch 135
# -------------------------------
# test_accuracy 0.099
# Epoch 136
# -------------------------------
# test_accuracy 0.0944
# Epoch 137
# -------------------------------
# test_accuracy 0.0985
# Epoch 138
# -------------------------------
# test_accuracy 0.0912
# Epoch 139
# -------------------------------
# test_accuracy 0.0946
# Epoch 140
# -------------------------------
# test_accuracy 0.1001
# Epoch 141
# -------------------------------
# test_accuracy 0.0949
# Epoch 142
# -------------------------------
# test_accuracy 0.0979
# Epoch 143
# -------------------------------
# test_accuracy 0.0953
# Epoch 144
# -------------------------------
# test_accuracy 0.0984
# Epoch 145
# -------------------------------
# test_accuracy 0.092
# Epoch 146
# -------------------------------
# test_accuracy 0.0891
# Epoch 147
# -------------------------------
# test_accuracy 0.0993
# Epoch 148
# -------------------------------
# test_accuracy 0.0936
# Epoch 149
# -------------------------------
# test_accuracy 0.0906
# Epoch 150
# -------------------------------
# test_accuracy 0.1004
# Epoch 151
# -------------------------------
# test_accuracy 0.0924
# Epoch 152
# -------------------------------
# test_accuracy 0.0897
# Epoch 153
# -------------------------------
# test_accuracy 0.0912
# Epoch 154
# -------------------------------
# test_accuracy 0.0932
# Epoch 155
# -------------------------------
# test_accuracy 0.0928
# Epoch 156
# -------------------------------
# test_accuracy 0.0968
# Epoch 157
# -------------------------------
# test_accuracy 0.0909
# Epoch 158
# -------------------------------
# test_accuracy 0.0917
# Epoch 159
# -------------------------------
# test_accuracy 0.0928
# Epoch 160
# -------------------------------
# test_accuracy 0.0943
# Epoch 161
# -------------------------------
# test_accuracy 0.0922
# Epoch 162
# -------------------------------
# test_accuracy 0.0962
# Epoch 163
# -------------------------------
# test_accuracy 0.089
# Epoch 164
# -------------------------------
# test_accuracy 0.0934
# Epoch 165
# -------------------------------
# test_accuracy 0.0928
# Epoch 166
# -------------------------------
# test_accuracy 0.0934
# Epoch 167
# -------------------------------
# test_accuracy 0.0939
# Epoch 168
# -------------------------------
# test_accuracy 0.0911
# Epoch 169
# -------------------------------
# test_accuracy 0.0951
# Epoch 170
# -------------------------------
# test_accuracy 0.0964
# Epoch 171
# -------------------------------
# test_accuracy 0.0937
# Epoch 172
# -------------------------------
# test_accuracy 0.0945
# Epoch 173
# -------------------------------
# test_accuracy 0.0967
# Epoch 174
# -------------------------------
# test_accuracy 0.0934
# Epoch 175
# -------------------------------
# test_accuracy 0.0935
# Epoch 176
# -------------------------------
# test_accuracy 0.0967
# Epoch 177
# -------------------------------
# test_accuracy 0.0899
# Epoch 178
# -------------------------------
# test_accuracy 0.0927
# Epoch 179
# -------------------------------
# test_accuracy 0.0906
# Epoch 180
# -------------------------------
# test_accuracy 0.0911
# Epoch 181
# -------------------------------
# test_accuracy 0.0915
# Epoch 182
# -------------------------------
# test_accuracy 0.1014
# Epoch 183
# -------------------------------
# test_accuracy 0.0924
# Epoch 184
# -------------------------------
# test_accuracy 0.0934
# Epoch 185
# -------------------------------
# test_accuracy 0.0923
# Epoch 186
# -------------------------------
# test_accuracy 0.0936
# Epoch 187
# -------------------------------
# test_accuracy 0.0925
# Epoch 188
# -------------------------------
# test_accuracy 0.093
# Epoch 189
# -------------------------------
# test_accuracy 0.0934
# Epoch 190
# -------------------------------
# test_accuracy 0.0924
# Epoch 191
# -------------------------------
# test_accuracy 0.0892
# Epoch 192
# -------------------------------
# test_accuracy 0.0938
# Epoch 193
# -------------------------------
# test_accuracy 0.0951
# Epoch 194
# -------------------------------
# test_accuracy 0.0916
# Epoch 195
# -------------------------------
# test_accuracy 0.0904
# Epoch 196
# -------------------------------
# test_accuracy 0.0912
# Epoch 197
# -------------------------------
# test_accuracy 0.0901
# Epoch 198
# -------------------------------
# test_accuracy 0.094
# Epoch 199
# -------------------------------
# test_accuracy 0.0945
# Epoch 200
# -------------------------------
# test_accuracy 0.0918
# [0.1087]
# Epoch 1
# -------------------------------
# test_accuracy 0.0724
# Epoch 2
# -------------------------------
# test_accuracy 0.0816
# Epoch 3
# -------------------------------
# test_accuracy 0.0726
# Epoch 4
# -------------------------------
# test_accuracy 0.0907
# Epoch 5
# -------------------------------
# test_accuracy 0.082
# Epoch 6
# -------------------------------
# test_accuracy 0.09
# Epoch 7
# -------------------------------
# test_accuracy 0.0829
# Epoch 8
# -------------------------------
# test_accuracy 0.0815
# Epoch 9
# -------------------------------
# test_accuracy 0.0925
# Epoch 10
# -------------------------------
# test_accuracy 0.0789
# Epoch 11
# -------------------------------
# test_accuracy 0.0684
# Epoch 12
# -------------------------------
# test_accuracy 0.0916
# Epoch 13
# -------------------------------
# test_accuracy 0.0861
# Epoch 14
# -------------------------------
# test_accuracy 0.0785
# Epoch 15
# -------------------------------
# test_accuracy 0.0857
# Epoch 16
# -------------------------------
# test_accuracy 0.0819
# Epoch 17
# -------------------------------
# test_accuracy 0.0791
# Epoch 18
# -------------------------------
# test_accuracy 0.0741
# Epoch 19
# -------------------------------
# test_accuracy 0.0788
# Epoch 20
# -------------------------------
# test_accuracy 0.09
# Epoch 21
# -------------------------------
# test_accuracy 0.0917
# Epoch 22
# -------------------------------
# test_accuracy 0.0906
# Epoch 23
# -------------------------------
# test_accuracy 0.0843
# Epoch 24
# -------------------------------
# test_accuracy 0.097
# Epoch 25
# -------------------------------
# test_accuracy 0.0976
# Epoch 26
# -------------------------------
# test_accuracy 0.1018
# Epoch 27
# -------------------------------
# test_accuracy 0.0862
# Epoch 28
# -------------------------------
# test_accuracy 0.0932
# Epoch 29
# -------------------------------
# test_accuracy 0.1015
# Epoch 30
# -------------------------------
# test_accuracy 0.0858
# Epoch 31
# -------------------------------
# test_accuracy 0.0919
# Epoch 32
# -------------------------------
# test_accuracy 0.0916
# Epoch 33
# -------------------------------
# test_accuracy 0.0999
# Epoch 34
# -------------------------------
# test_accuracy 0.0935
# Epoch 35
# -------------------------------
# test_accuracy 0.0948
# Epoch 36
# -------------------------------
# test_accuracy 0.105
# Epoch 37
# -------------------------------
# test_accuracy 0.1052
# Epoch 38
# -------------------------------
# test_accuracy 0.0988
# Epoch 39
# -------------------------------
# test_accuracy 0.0939
# Epoch 40
# -------------------------------
# test_accuracy 0.0908
# Epoch 41
# -------------------------------
# test_accuracy 0.0973
# Epoch 42
# -------------------------------
# test_accuracy 0.0903
# Epoch 43
# -------------------------------
# test_accuracy 0.0887
# Epoch 44
# -------------------------------
# test_accuracy 0.0969
# Epoch 45
# -------------------------------
# test_accuracy 0.0931
# Epoch 46
# -------------------------------
# test_accuracy 0.0959
# Epoch 47
# -------------------------------
# test_accuracy 0.0968
# Epoch 48
# -------------------------------
# test_accuracy 0.1015
# Epoch 49
# -------------------------------
# test_accuracy 0.1012
# Epoch 50
# -------------------------------
# test_accuracy 0.0986
# Epoch 51
# -------------------------------
# test_accuracy 0.0946
# Epoch 52
# -------------------------------
# test_accuracy 0.0991
# Epoch 53
# -------------------------------
# test_accuracy 0.093
# Epoch 54
# -------------------------------
# test_accuracy 0.0992
# Epoch 55
# -------------------------------
# test_accuracy 0.0919
# Epoch 56
# -------------------------------
# test_accuracy 0.0924
# Epoch 57
# -------------------------------
# test_accuracy 0.0957
# Epoch 58
# -------------------------------
# test_accuracy 0.1038
# Epoch 59
# -------------------------------
# test_accuracy 0.0968
# Epoch 60
# -------------------------------
# test_accuracy 0.0995
# Epoch 61
# -------------------------------
# test_accuracy 0.0991
# Epoch 62
# -------------------------------
# test_accuracy 0.096
# Epoch 63
# -------------------------------
# test_accuracy 0.1049
# Epoch 64
# -------------------------------
# test_accuracy 0.1018
# Epoch 65
# -------------------------------
# test_accuracy 0.1009
# Epoch 66
# -------------------------------
# test_accuracy 0.0897
# Epoch 67
# -------------------------------
# test_accuracy 0.0996
# Epoch 68
# -------------------------------
# test_accuracy 0.095
# Epoch 69
# -------------------------------
# test_accuracy 0.0994
# Epoch 70
# -------------------------------
# test_accuracy 0.0995
# Epoch 71
# -------------------------------
# test_accuracy 0.095
# Epoch 72
# -------------------------------
# test_accuracy 0.1003
# Epoch 73
# -------------------------------
# test_accuracy 0.1029
# Epoch 74
# -------------------------------
# test_accuracy 0.0966
# Epoch 75
# -------------------------------
# test_accuracy 0.1013
# Epoch 76
# -------------------------------
# test_accuracy 0.1036
# Epoch 77
# -------------------------------
# test_accuracy 0.0933
# Epoch 78
# -------------------------------
# test_accuracy 0.0954
# Epoch 79
# -------------------------------
# test_accuracy 0.1008
# Epoch 80
# -------------------------------
# test_accuracy 0.105
# Epoch 81
# -------------------------------
# test_accuracy 0.0938
# Epoch 82
# -------------------------------
# test_accuracy 0.099
# Epoch 83
# -------------------------------
# test_accuracy 0.0941
# Epoch 84
# -------------------------------
# test_accuracy 0.0946
# Epoch 85
# -------------------------------
# test_accuracy 0.1002
# Epoch 86
# -------------------------------
# test_accuracy 0.1009
# Epoch 87
# -------------------------------
# test_accuracy 0.0983
# Epoch 88
# -------------------------------
# test_accuracy 0.0992
# Epoch 89
# -------------------------------
# test_accuracy 0.0969
# Epoch 90
# -------------------------------
# test_accuracy 0.0955
# Epoch 91
# -------------------------------
# test_accuracy 0.1014
# Epoch 92
# -------------------------------
# test_accuracy 0.1024
# Epoch 93
# -------------------------------
# test_accuracy 0.0996
# Epoch 94
# -------------------------------
# test_accuracy 0.0977
# Epoch 95
# -------------------------------
# test_accuracy 0.0959
# Epoch 96
# -------------------------------
# test_accuracy 0.1006
# Epoch 97
# -------------------------------
# test_accuracy 0.1019
# Epoch 98
# -------------------------------
# test_accuracy 0.1011
# Epoch 99
# -------------------------------
# test_accuracy 0.095
# Epoch 100
# -------------------------------
# test_accuracy 0.0964
# Epoch 101
# -------------------------------
# test_accuracy 0.1015
# Epoch 102
# -------------------------------
# test_accuracy 0.0953
# Epoch 103
# -------------------------------
# test_accuracy 0.1011
# Epoch 104
# -------------------------------
# test_accuracy 0.0951
# Epoch 105
# -------------------------------
# test_accuracy 0.1008
# Epoch 106
# -------------------------------
# test_accuracy 0.1024
# Epoch 107
# -------------------------------
# test_accuracy 0.0948
# Epoch 108
# -------------------------------
# test_accuracy 0.103
# Epoch 109
# -------------------------------
# test_accuracy 0.0963
# Epoch 110
# -------------------------------
# test_accuracy 0.1011
# Epoch 111
# -------------------------------
# test_accuracy 0.0992
# Epoch 112
# -------------------------------
# test_accuracy 0.0966
# Epoch 113
# -------------------------------
# test_accuracy 0.1017
# Epoch 114
# -------------------------------
# test_accuracy 0.0961
# Epoch 115
# -------------------------------
# test_accuracy 0.0998
# Epoch 116
# -------------------------------
# test_accuracy 0.1003
# Epoch 117
# -------------------------------
# test_accuracy 0.0922
# Epoch 118
# -------------------------------
# test_accuracy 0.1021
# Epoch 119
# -------------------------------
# test_accuracy 0.0948
# Epoch 120
# -------------------------------
# test_accuracy 0.0946
# Epoch 121
# -------------------------------
# test_accuracy 0.0969
# Epoch 122
# -------------------------------
# test_accuracy 0.0985
# Epoch 123
# -------------------------------
# test_accuracy 0.0937
# Epoch 124
# -------------------------------
# test_accuracy 0.0953
# Epoch 125
# -------------------------------
# test_accuracy 0.0956
# Epoch 126
# -------------------------------
# test_accuracy 0.0897
# Epoch 127
# -------------------------------
# test_accuracy 0.0997
# Epoch 128
# -------------------------------
# test_accuracy 0.098
# Epoch 129
# -------------------------------
# test_accuracy 0.0947
# Epoch 130
# -------------------------------
# test_accuracy 0.0909
# Epoch 131
# -------------------------------
# test_accuracy 0.0987
# Epoch 132
# -------------------------------
# test_accuracy 0.0956
# Epoch 133
# -------------------------------
# test_accuracy 0.0972
# Epoch 134
# -------------------------------
# test_accuracy 0.095
# Epoch 135
# -------------------------------
# test_accuracy 0.0951
# Epoch 136
# -------------------------------
# test_accuracy 0.0942
# Epoch 137
# -------------------------------
# test_accuracy 0.0934
# Epoch 138
# -------------------------------
# test_accuracy 0.0958
# Epoch 139
# -------------------------------
# test_accuracy 0.0916
# Epoch 140
# -------------------------------
# test_accuracy 0.0942
# Epoch 141
# -------------------------------
# test_accuracy 0.096
# Epoch 142
# -------------------------------
# test_accuracy 0.0931
# Epoch 143
# -------------------------------
# test_accuracy 0.0975
# Epoch 144
# -------------------------------
# test_accuracy 0.0933
# Epoch 145
# -------------------------------
# test_accuracy 0.0939
# Epoch 146
# -------------------------------
# test_accuracy 0.0983
# Epoch 147
# -------------------------------
# test_accuracy 0.0913
# Epoch 148
# -------------------------------
# test_accuracy 0.0972
# Epoch 149
# -------------------------------
# test_accuracy 0.0951
# Epoch 150
# -------------------------------
# test_accuracy 0.0887
# Epoch 151
# -------------------------------
# test_accuracy 0.0955
# Epoch 152
# -------------------------------
# test_accuracy 0.0967
# Epoch 153
# -------------------------------
# test_accuracy 0.0963
# Epoch 154
# -------------------------------
# test_accuracy 0.0981
# Epoch 155
# -------------------------------
# test_accuracy 0.0983
# Epoch 156
# -------------------------------
# test_accuracy 0.0927
# Epoch 157
# -------------------------------
# test_accuracy 0.0976
# Epoch 158
# -------------------------------
# test_accuracy 0.0939
# Epoch 159
# -------------------------------
# test_accuracy 0.096
# Epoch 160
# -------------------------------
# test_accuracy 0.0928
# Epoch 161
# -------------------------------
# test_accuracy 0.0917
# Epoch 162
# -------------------------------
# test_accuracy 0.0953
# Epoch 163
# -------------------------------
# test_accuracy 0.0946
# Epoch 164
# -------------------------------
# test_accuracy 0.0969
# Epoch 165
# -------------------------------
# test_accuracy 0.0938
# Epoch 166
# -------------------------------
# test_accuracy 0.0924
# Epoch 167
# -------------------------------
# test_accuracy 0.0917
# Epoch 168
# -------------------------------
# test_accuracy 0.095
# Epoch 169
# -------------------------------
# test_accuracy 0.0956
# Epoch 170
# -------------------------------
# test_accuracy 0.0953
# Epoch 171
# -------------------------------
# test_accuracy 0.0924
# Epoch 172
# -------------------------------
# test_accuracy 0.0938
# Epoch 173
# -------------------------------
# test_accuracy 0.0913
# Epoch 174
# -------------------------------
# test_accuracy 0.096
# Epoch 175
# -------------------------------
# test_accuracy 0.0944
# Epoch 176
# -------------------------------
# test_accuracy 0.0939
# Epoch 177
# -------------------------------
# test_accuracy 0.0939
# Epoch 178
# -------------------------------
# test_accuracy 0.0935
# Epoch 179
# -------------------------------
# test_accuracy 0.0927
# Epoch 180
# -------------------------------
# test_accuracy 0.0945
# Epoch 181
# -------------------------------
# test_accuracy 0.0905
# Epoch 182
# -------------------------------
# test_accuracy 0.0923
# Epoch 183
# -------------------------------
# test_accuracy 0.095
# Epoch 184
# -------------------------------
# test_accuracy 0.0913
# Epoch 185
# -------------------------------
# test_accuracy 0.0936
# Epoch 186
# -------------------------------
# test_accuracy 0.0922
# Epoch 187
# -------------------------------
# test_accuracy 0.0928
# Epoch 188
# -------------------------------
# test_accuracy 0.0908
# Epoch 189
# -------------------------------
# test_accuracy 0.0918
# Epoch 190
# -------------------------------
# test_accuracy 0.0917
# Epoch 191
# -------------------------------
# test_accuracy 0.0912
# Epoch 192
# -------------------------------
# test_accuracy 0.0901
# Epoch 193
# -------------------------------
# test_accuracy 0.0964
# Epoch 194
# -------------------------------
# test_accuracy 0.0932
# Epoch 195
# -------------------------------
# test_accuracy 0.0901
# Epoch 196
# -------------------------------
# test_accuracy 0.0906
# Epoch 197
# -------------------------------
# test_accuracy 0.0878
# Epoch 198
# -------------------------------
# test_accuracy 0.0909
# Epoch 199
# -------------------------------
# test_accuracy 0.0903
# Epoch 200
# -------------------------------
# test_accuracy 0.0894
# [0.1087, 0.1052]
# Epoch 1
# -------------------------------
# test_accuracy 0.0559
# Epoch 2
# -------------------------------
# test_accuracy 0.0601
# Epoch 3
# -------------------------------
# test_accuracy 0.0947
# Epoch 4
# -------------------------------
# test_accuracy 0.0777
# Epoch 5
# -------------------------------
# test_accuracy 0.0665
# Epoch 6
# -------------------------------
# test_accuracy 0.0825
# Epoch 7
# -------------------------------
# test_accuracy 0.081
# Epoch 8
# -------------------------------
# test_accuracy 0.0829
# Epoch 9
# -------------------------------
# test_accuracy 0.0692
# Epoch 10
# -------------------------------
# test_accuracy 0.0944
# Epoch 11
# -------------------------------
# test_accuracy 0.1023
# Epoch 12
# -------------------------------
# test_accuracy 0.0923
# Epoch 13
# -------------------------------
# test_accuracy 0.0891
# Epoch 14
# -------------------------------
# test_accuracy 0.0738
# Epoch 15
# -------------------------------
# test_accuracy 0.0879
# Epoch 16
# -------------------------------
# test_accuracy 0.092
# Epoch 17
# -------------------------------
# test_accuracy 0.0839
# Epoch 18
# -------------------------------
# test_accuracy 0.1019
# Epoch 19
# -------------------------------
# test_accuracy 0.0901
# Epoch 20
# -------------------------------
# test_accuracy 0.0951
# Epoch 21
# -------------------------------
# test_accuracy 0.0848
# Epoch 22
# -------------------------------
# test_accuracy 0.1009
# Epoch 23
# -------------------------------
# test_accuracy 0.0958
# Epoch 24
# -------------------------------
# test_accuracy 0.0916
# Epoch 25
# -------------------------------
# test_accuracy 0.0924
# Epoch 26
# -------------------------------
# test_accuracy 0.0899
# Epoch 27
# -------------------------------
# test_accuracy 0.099
# Epoch 28
# -------------------------------
# test_accuracy 0.0999
# Epoch 29
# -------------------------------
# test_accuracy 0.0915
# Epoch 30
# -------------------------------
# test_accuracy 0.0922
# Epoch 31
# -------------------------------
# test_accuracy 0.0941
# Epoch 32
# -------------------------------
# test_accuracy 0.0805
# Epoch 33
# -------------------------------
# test_accuracy 0.0924
# Epoch 34
# -------------------------------
# test_accuracy 0.0986
# Epoch 35
# -------------------------------
# test_accuracy 0.0936
# Epoch 36
# -------------------------------
# test_accuracy 0.0932
# Epoch 37
# -------------------------------
# test_accuracy 0.0937
# Epoch 38
# -------------------------------
# test_accuracy 0.0977
# Epoch 39
# -------------------------------
# test_accuracy 0.0961
# Epoch 40
# -------------------------------
# test_accuracy 0.0891
# Epoch 41
# -------------------------------
# test_accuracy 0.0991
# Epoch 42
# -------------------------------
# test_accuracy 0.0987
# Epoch 43
# -------------------------------
# test_accuracy 0.093
# Epoch 44
# -------------------------------
# test_accuracy 0.1094
# Epoch 45
# -------------------------------
# test_accuracy 0.0934
# Epoch 46
# -------------------------------
# test_accuracy 0.092
# Epoch 47
# -------------------------------
# test_accuracy 0.09
# Epoch 48
# -------------------------------
# test_accuracy 0.1054
# Epoch 49
# -------------------------------
# test_accuracy 0.1013
# Epoch 50
# -------------------------------
# test_accuracy 0.0972
# Epoch 51
# -------------------------------
# test_accuracy 0.0978
# Epoch 52
# -------------------------------
# test_accuracy 0.0993
# Epoch 53
# -------------------------------
# test_accuracy 0.1026
# Epoch 54
# -------------------------------
# test_accuracy 0.0992
# Epoch 55
# -------------------------------
# test_accuracy 0.0933
# Epoch 56
# -------------------------------
# test_accuracy 0.0982
# Epoch 57
# -------------------------------
# test_accuracy 0.0944
# Epoch 58
# -------------------------------
# test_accuracy 0.0961
# Epoch 59
# -------------------------------
# test_accuracy 0.1037
# Epoch 60
# -------------------------------
# test_accuracy 0.1094
# Epoch 61
# -------------------------------
# test_accuracy 0.0889
# Epoch 62
# -------------------------------
# test_accuracy 0.0996
# Epoch 63
# -------------------------------
# test_accuracy 0.1058
# Epoch 64
# -------------------------------
# test_accuracy 0.0998
# Epoch 65
# -------------------------------
# test_accuracy 0.099
# Epoch 66
# -------------------------------
# test_accuracy 0.096
# Epoch 67
# -------------------------------
# test_accuracy 0.0985
# Epoch 68
# -------------------------------
# test_accuracy 0.0985
# Epoch 69
# -------------------------------
# test_accuracy 0.0941
# Epoch 70
# -------------------------------
# test_accuracy 0.1049
# Epoch 71
# -------------------------------
# test_accuracy 0.0983
# Epoch 72
# -------------------------------
# test_accuracy 0.1012
# Epoch 73
# -------------------------------
# test_accuracy 0.1021
# Epoch 74
# -------------------------------
# test_accuracy 0.0974
# Epoch 75
# -------------------------------
# test_accuracy 0.096
# Epoch 76
# -------------------------------
# test_accuracy 0.0992
# Epoch 77
# -------------------------------
# test_accuracy 0.0976
# Epoch 78
# -------------------------------
# test_accuracy 0.1016
# Epoch 79
# -------------------------------
# test_accuracy 0.0957
# Epoch 80
# -------------------------------
# test_accuracy 0.1002
# Epoch 81
# -------------------------------
# test_accuracy 0.0964
# Epoch 82
# -------------------------------
# test_accuracy 0.1016
# Epoch 83
# -------------------------------
# test_accuracy 0.0966
# Epoch 84
# -------------------------------
# test_accuracy 0.0998
# Epoch 85
# -------------------------------
# test_accuracy 0.0995
# Epoch 86
# -------------------------------
# test_accuracy 0.0994
# Epoch 87
# -------------------------------
# test_accuracy 0.1028
# Epoch 88
# -------------------------------
# test_accuracy 0.1005
# Epoch 89
# -------------------------------
# test_accuracy 0.1003
# Epoch 90
# -------------------------------
# test_accuracy 0.0964
# Epoch 91
# -------------------------------
# test_accuracy 0.0979
# Epoch 92
# -------------------------------
# test_accuracy 0.0974
# Epoch 93
# -------------------------------
# test_accuracy 0.0992
# Epoch 94
# -------------------------------
# test_accuracy 0.1012
# Epoch 95
# -------------------------------
# test_accuracy 0.1002
# Epoch 96
# -------------------------------
# test_accuracy 0.1003
# Epoch 97
# -------------------------------
# test_accuracy 0.0959
# Epoch 98
# -------------------------------
# test_accuracy 0.0955
# Epoch 99
# -------------------------------
# test_accuracy 0.0957
# Epoch 100
# -------------------------------
# test_accuracy 0.1004
# Epoch 101
# -------------------------------
# test_accuracy 0.0987
# Epoch 102
# -------------------------------
# test_accuracy 0.1
# Epoch 103
# -------------------------------
# test_accuracy 0.0964
# Epoch 104
# -------------------------------
# test_accuracy 0.0914
# Epoch 105
# -------------------------------
# test_accuracy 0.1001
# Epoch 106
# -------------------------------
# test_accuracy 0.0969
# Epoch 107
# -------------------------------
# test_accuracy 0.1028
# Epoch 108
# -------------------------------
# test_accuracy 0.0949
# Epoch 109
# -------------------------------
# test_accuracy 0.0987
# Epoch 110
# -------------------------------
# test_accuracy 0.1008
# Epoch 111
# -------------------------------
# test_accuracy 0.1033
# Epoch 112
# -------------------------------
# test_accuracy 0.1031
# Epoch 113
# -------------------------------
# test_accuracy 0.0974
# Epoch 114
# -------------------------------
# test_accuracy 0.099
# Epoch 115
# -------------------------------
# test_accuracy 0.102
# Epoch 116
# -------------------------------
# test_accuracy 0.0996
# Epoch 117
# -------------------------------
# test_accuracy 0.1003
# Epoch 118
# -------------------------------
# test_accuracy 0.1004
# Epoch 119
# -------------------------------
# test_accuracy 0.1001
# Epoch 120
# -------------------------------
# test_accuracy 0.0927
# Epoch 121
# -------------------------------
# test_accuracy 0.0975
# Epoch 122
# -------------------------------
# test_accuracy 0.0937
# Epoch 123
# -------------------------------
# test_accuracy 0.0997
# Epoch 124
# -------------------------------
# test_accuracy 0.095
# Epoch 125
# -------------------------------
# test_accuracy 0.0937
# Epoch 126
# -------------------------------
# test_accuracy 0.0963
# Epoch 127
# -------------------------------
# test_accuracy 0.098
# Epoch 128
# -------------------------------
# test_accuracy 0.096
# Epoch 129
# -------------------------------
# test_accuracy 0.0964
# Epoch 130
# -------------------------------
# test_accuracy 0.0963
# Epoch 131
# -------------------------------
# test_accuracy 0.098
# Epoch 132
# -------------------------------
# test_accuracy 0.0995
# Epoch 133
# -------------------------------
# test_accuracy 0.0974
# Epoch 134
# -------------------------------
# test_accuracy 0.0945
# Epoch 135
# -------------------------------
# test_accuracy 0.095
# Epoch 136
# -------------------------------
# test_accuracy 0.1027
# Epoch 137
# -------------------------------
# test_accuracy 0.0962
# Epoch 138
# -------------------------------
# test_accuracy 0.0982
# Epoch 139
# -------------------------------
# test_accuracy 0.0938
# Epoch 140
# -------------------------------
# test_accuracy 0.0932
# Epoch 141
# -------------------------------
# test_accuracy 0.097
# Epoch 142
# -------------------------------
# test_accuracy 0.0932
# Epoch 143
# -------------------------------
# test_accuracy 0.0953
# Epoch 144
# -------------------------------
# test_accuracy 0.0968
# Epoch 145
# -------------------------------
# test_accuracy 0.0902
# Epoch 146
# -------------------------------
# test_accuracy 0.0942
# Epoch 147
# -------------------------------
# test_accuracy 0.0904
# Epoch 148
# -------------------------------
# test_accuracy 0.0898
# Epoch 149
# -------------------------------
# test_accuracy 0.0938
# Epoch 150
# -------------------------------
# test_accuracy 0.0929
# Epoch 151
# -------------------------------
# test_accuracy 0.0925
# Epoch 152
# -------------------------------
# test_accuracy 0.0945
# Epoch 153
# -------------------------------
# test_accuracy 0.0925
# Epoch 154
# -------------------------------
# test_accuracy 0.0917
# Epoch 155
# -------------------------------
# test_accuracy 0.0945
# Epoch 156
# -------------------------------
# test_accuracy 0.0937
# Epoch 157
# -------------------------------
# test_accuracy 0.0973
# Epoch 158
# -------------------------------
# test_accuracy 0.0948
# Epoch 159
# -------------------------------
# test_accuracy 0.0926
# Epoch 160
# -------------------------------
# test_accuracy 0.0935
# Epoch 161
# -------------------------------
# test_accuracy 0.0921
# Epoch 162
# -------------------------------
# test_accuracy 0.0944
# Epoch 163
# -------------------------------
# test_accuracy 0.0926
# Epoch 164
# -------------------------------
# test_accuracy 0.0929
# Epoch 165
# -------------------------------
# test_accuracy 0.0931
# Epoch 166
# -------------------------------
# test_accuracy 0.0896
# Epoch 167
# -------------------------------
# test_accuracy 0.0961
# Epoch 168
# -------------------------------
# test_accuracy 0.0923
# Epoch 169
# -------------------------------
# test_accuracy 0.0929
# Epoch 170
# -------------------------------
# test_accuracy 0.0907
# Epoch 171
# -------------------------------
# test_accuracy 0.0926
# Epoch 172
# -------------------------------
# test_accuracy 0.0962
# Epoch 173
# -------------------------------
# test_accuracy 0.093
# Epoch 174
# -------------------------------
# test_accuracy 0.0942
# Epoch 175
# -------------------------------
# test_accuracy 0.0917
# Epoch 176
# -------------------------------
# test_accuracy 0.098
# Epoch 177
# -------------------------------
# test_accuracy 0.0932
# Epoch 178
# -------------------------------
# test_accuracy 0.0918
# Epoch 179
# -------------------------------
# test_accuracy 0.0936
# Epoch 180
# -------------------------------
# test_accuracy 0.0905
# Epoch 181
# -------------------------------
# test_accuracy 0.0906
# Epoch 182
# -------------------------------
# test_accuracy 0.0942
# Epoch 183
# -------------------------------
# test_accuracy 0.0933
# Epoch 184
# -------------------------------
# test_accuracy 0.0899
# Epoch 185
# -------------------------------
# test_accuracy 0.0926
# Epoch 186
# -------------------------------
# test_accuracy 0.0942
# Epoch 187
# -------------------------------
# test_accuracy 0.0934
# Epoch 188
# -------------------------------
# test_accuracy 0.0913
# Epoch 189
# -------------------------------
# test_accuracy 0.0935
# Epoch 190
# -------------------------------
# test_accuracy 0.0933
# Epoch 191
# -------------------------------
# test_accuracy 0.09
# Epoch 192
# -------------------------------
# test_accuracy 0.0919
# Epoch 193
# -------------------------------
# test_accuracy 0.0925
# Epoch 194
# -------------------------------
# test_accuracy 0.0945
# Epoch 195
# -------------------------------
# test_accuracy 0.0897
# Epoch 196
# -------------------------------
# test_accuracy 0.0891
# Epoch 197
# -------------------------------
# test_accuracy 0.093
# Epoch 198
# -------------------------------
# test_accuracy 0.0912
# Epoch 199
# -------------------------------
# test_accuracy 0.0891
# Epoch 200
# -------------------------------
# test_accuracy 0.0885
# [0.1087, 0.1052, 0.1094]
# Epoch 1
# -------------------------------
# test_accuracy 0.0563
# Epoch 2
# -------------------------------
# test_accuracy 0.0579
# Epoch 3
# -------------------------------
# test_accuracy 0.0662
# Epoch 4
# -------------------------------
# test_accuracy 0.0755
# Epoch 5
# -------------------------------
# test_accuracy 0.0773
# Epoch 6
# -------------------------------
# test_accuracy 0.0706
# Epoch 7
# -------------------------------
# test_accuracy 0.0834
# Epoch 8
# -------------------------------
# test_accuracy 0.0788
# Epoch 9
# -------------------------------
# test_accuracy 0.0883
# Epoch 10
# -------------------------------
# test_accuracy 0.0702
# Epoch 11
# -------------------------------
# test_accuracy 0.0907
# Epoch 12
# -------------------------------
# test_accuracy 0.0756
# Epoch 13
# -------------------------------
# test_accuracy 0.0941
# Epoch 14
# -------------------------------
# test_accuracy 0.0899
# Epoch 15
# -------------------------------
# test_accuracy 0.092
# Epoch 16
# -------------------------------
# test_accuracy 0.0912
# Epoch 17
# -------------------------------
# test_accuracy 0.0888
# Epoch 18
# -------------------------------
# test_accuracy 0.0845
# Epoch 19
# -------------------------------
# test_accuracy 0.0961
# Epoch 20
# -------------------------------
# test_accuracy 0.0983
# Epoch 21
# -------------------------------
# test_accuracy 0.0942
# Epoch 22
# -------------------------------
# test_accuracy 0.0824
# Epoch 23
# -------------------------------
# test_accuracy 0.0858
# Epoch 24
# -------------------------------
# test_accuracy 0.0977
# Epoch 25
# -------------------------------
# test_accuracy 0.1088
# Epoch 26
# -------------------------------
# test_accuracy 0.0976
# Epoch 27
# -------------------------------
# test_accuracy 0.0897
# Epoch 28
# -------------------------------
# test_accuracy 0.0928
# Epoch 29
# -------------------------------
# test_accuracy 0.1049
# Epoch 30
# -------------------------------
# test_accuracy 0.0844
# Epoch 31
# -------------------------------
# test_accuracy 0.0936
# Epoch 32
# -------------------------------
# test_accuracy 0.0979
# Epoch 33
# -------------------------------
# test_accuracy 0.0813
# Epoch 34
# -------------------------------
# test_accuracy 0.0937
# Epoch 35
# -------------------------------
# test_accuracy 0.1033
# Epoch 36
# -------------------------------
# test_accuracy 0.0871
# Epoch 37
# -------------------------------
# test_accuracy 0.102
# Epoch 38
# -------------------------------
# test_accuracy 0.0918
# Epoch 39
# -------------------------------
# test_accuracy 0.0966
# Epoch 40
# -------------------------------
# test_accuracy 0.1012
# Epoch 41
# -------------------------------
# test_accuracy 0.1063
# Epoch 42
# -------------------------------
# test_accuracy 0.0997
# Epoch 43
# -------------------------------
# test_accuracy 0.0914
# Epoch 44
# -------------------------------
# test_accuracy 0.096
# Epoch 45
# -------------------------------
# test_accuracy 0.093
# Epoch 46
# -------------------------------
# test_accuracy 0.1044
# Epoch 47
# -------------------------------
# test_accuracy 0.0993
# Epoch 48
# -------------------------------
# test_accuracy 0.0982
# Epoch 49
# -------------------------------
# test_accuracy 0.1041
# Epoch 50
# -------------------------------
# test_accuracy 0.0927
# Epoch 51
# -------------------------------
# test_accuracy 0.1035
# Epoch 52
# -------------------------------
# test_accuracy 0.1065
# Epoch 53
# -------------------------------
# test_accuracy 0.1032
# Epoch 54
# -------------------------------
# test_accuracy 0.0931
# Epoch 55
# -------------------------------
# test_accuracy 0.0999
# Epoch 56
# -------------------------------
# test_accuracy 0.1011
# Epoch 57
# -------------------------------
# test_accuracy 0.095
# Epoch 58
# -------------------------------
# test_accuracy 0.0982
# Epoch 59
# -------------------------------
# test_accuracy 0.0966
# Epoch 60
# -------------------------------
# test_accuracy 0.102
# Epoch 61
# -------------------------------
# test_accuracy 0.0985
# Epoch 62
# -------------------------------
# test_accuracy 0.1014
# Epoch 63
# -------------------------------
# test_accuracy 0.0977
# Epoch 64
# -------------------------------
# test_accuracy 0.0986
# Epoch 65
# -------------------------------
# test_accuracy 0.0971
# Epoch 66
# -------------------------------
# test_accuracy 0.1017
# Epoch 67
# -------------------------------
# test_accuracy 0.0951
# Epoch 68
# -------------------------------
# test_accuracy 0.0975
# Epoch 69
# -------------------------------
# test_accuracy 0.0993
# Epoch 70
# -------------------------------
# test_accuracy 0.0954
# Epoch 71
# -------------------------------
# test_accuracy 0.0971
# Epoch 72
# -------------------------------
# test_accuracy 0.1017
# Epoch 73
# -------------------------------
# test_accuracy 0.1092
# Epoch 74
# -------------------------------
# test_accuracy 0.092
# Epoch 75
# -------------------------------
# test_accuracy 0.1007
# Epoch 76
# -------------------------------
# test_accuracy 0.1056
# Epoch 77
# -------------------------------
# test_accuracy 0.0989
# Epoch 78
# -------------------------------
# test_accuracy 0.1014
# Epoch 79
# -------------------------------
# test_accuracy 0.1036
# Epoch 80
# -------------------------------
# test_accuracy 0.0985
# Epoch 81
# -------------------------------
# test_accuracy 0.1091
# Epoch 82
# -------------------------------
# test_accuracy 0.0965
# Epoch 83
# -------------------------------
# test_accuracy 0.0973
# Epoch 84
# -------------------------------
# test_accuracy 0.1015
# Epoch 85
# -------------------------------
# test_accuracy 0.0948
# Epoch 86
# -------------------------------
# test_accuracy 0.1032
# Epoch 87
# -------------------------------
# test_accuracy 0.0982
# Epoch 88
# -------------------------------
# test_accuracy 0.0994
# Epoch 89
# -------------------------------
# test_accuracy 0.0999
# Epoch 90
# -------------------------------
# test_accuracy 0.1009
# Epoch 91
# -------------------------------
# test_accuracy 0.1006
# Epoch 92
# -------------------------------
# test_accuracy 0.1005
# Epoch 93
# -------------------------------
# test_accuracy 0.0968
# Epoch 94
# -------------------------------
# test_accuracy 0.0977
# Epoch 95
# -------------------------------
# test_accuracy 0.102
# Epoch 96
# -------------------------------
# test_accuracy 0.0965
# Epoch 97
# -------------------------------
# test_accuracy 0.0987
# Epoch 98
# -------------------------------
# test_accuracy 0.0978
# Epoch 99
# -------------------------------
# test_accuracy 0.0977
# Epoch 100
# -------------------------------
# test_accuracy 0.0964
# Epoch 101
# -------------------------------
# test_accuracy 0.0983
# Epoch 102
# -------------------------------
# test_accuracy 0.0979
# Epoch 103
# -------------------------------
# test_accuracy 0.0973
# Epoch 104
# -------------------------------
# test_accuracy 0.099
# Epoch 105
# -------------------------------
# test_accuracy 0.0968
# Epoch 106
# -------------------------------
# test_accuracy 0.1014
# Epoch 107
# -------------------------------
# test_accuracy 0.0981
# Epoch 108
# -------------------------------
# test_accuracy 0.098
# Epoch 109
# -------------------------------
# test_accuracy 0.0955
# Epoch 110
# -------------------------------
# test_accuracy 0.0974
# Epoch 111
# -------------------------------
# test_accuracy 0.0974
# Epoch 112
# -------------------------------
# test_accuracy 0.0997
# Epoch 113
# -------------------------------
# test_accuracy 0.1002
# Epoch 114
# -------------------------------
# test_accuracy 0.0953
# Epoch 115
# -------------------------------
# test_accuracy 0.0939
# Epoch 116
# -------------------------------
# test_accuracy 0.1007
# Epoch 117
# -------------------------------
# test_accuracy 0.1001
# Epoch 118
# -------------------------------
# test_accuracy 0.0962
# Epoch 119
# -------------------------------
# test_accuracy 0.0992
# Epoch 120
# -------------------------------
# test_accuracy 0.0972
# Epoch 121
# -------------------------------
# test_accuracy 0.0967
# Epoch 122
# -------------------------------
# test_accuracy 0.0982
# Epoch 123
# -------------------------------
# test_accuracy 0.0948
# Epoch 124
# -------------------------------
# test_accuracy 0.0945
# Epoch 125
# -------------------------------
# test_accuracy 0.096
# Epoch 126
# -------------------------------
# test_accuracy 0.0976
# Epoch 127
# -------------------------------
# test_accuracy 0.0947
# Epoch 128
# -------------------------------
# test_accuracy 0.0983
# Epoch 129
# -------------------------------
# test_accuracy 0.0955
# Epoch 130
# -------------------------------
# test_accuracy 0.0962
# Epoch 131
# -------------------------------
# test_accuracy 0.0969
# Epoch 132
# -------------------------------
# test_accuracy 0.0989
# Epoch 133
# -------------------------------
# test_accuracy 0.0986
# Epoch 134
# -------------------------------
# test_accuracy 0.0963
# Epoch 135
# -------------------------------
# test_accuracy 0.0959
# Epoch 136
# -------------------------------
# test_accuracy 0.0992
# Epoch 137
# -------------------------------
# test_accuracy 0.0959
# Epoch 138
# -------------------------------
# test_accuracy 0.0972
# Epoch 139
# -------------------------------
# test_accuracy 0.0941
# Epoch 140
# -------------------------------
# test_accuracy 0.094
# Epoch 141
# -------------------------------
# test_accuracy 0.0957
# Epoch 142
# -------------------------------
# test_accuracy 0.0945
# Epoch 143
# -------------------------------
# test_accuracy 0.0932
# Epoch 144
# -------------------------------
# test_accuracy 0.0964
# Epoch 145
# -------------------------------
# test_accuracy 0.0939
# Epoch 146
# -------------------------------
# test_accuracy 0.098
# Epoch 147
# -------------------------------
# test_accuracy 0.0929
# Epoch 148
# -------------------------------
# test_accuracy 0.0925
# Epoch 149
# -------------------------------
# test_accuracy 0.0968
# Epoch 150
# -------------------------------
# test_accuracy 0.0961
# Epoch 151
# -------------------------------
# test_accuracy 0.0964
# Epoch 152
# -------------------------------
# test_accuracy 0.0953
# Epoch 153
# -------------------------------
# test_accuracy 0.0949
# Epoch 154
# -------------------------------
# test_accuracy 0.0897
# Epoch 155
# -------------------------------
# test_accuracy 0.0964
# Epoch 156
# -------------------------------
# test_accuracy 0.0964
# Epoch 157
# -------------------------------
# test_accuracy 0.093
# Epoch 158
# -------------------------------
# test_accuracy 0.0947
# Epoch 159
# -------------------------------
# test_accuracy 0.0957
# Epoch 160
# -------------------------------
# test_accuracy 0.0934
# Epoch 161
# -------------------------------
# test_accuracy 0.0915
# Epoch 162
# -------------------------------
# test_accuracy 0.094
# Epoch 163
# -------------------------------
# test_accuracy 0.0927
# Epoch 164
# -------------------------------
# test_accuracy 0.0944
# Epoch 165
# -------------------------------
# test_accuracy 0.0957
# Epoch 166
# -------------------------------
# test_accuracy 0.0911
# Epoch 167
# -------------------------------
# test_accuracy 0.0972
# Epoch 168
# -------------------------------
# test_accuracy 0.0919
# Epoch 169
# -------------------------------
# test_accuracy 0.0938
# Epoch 170
# ...
# test_accuracy 0.0946
# Epoch 153
# -------------------------------
# test_accuracy 0.0952
# Epoch 154
# -------------------------------
# test_accuracy 0.0962
# Epoch 155
# -------------------------------
# test_accuracy 0.0935
# Epoch 156
# -------------------------------
# test_accuracy 0.0897
# Epoch 157
# -------------------------------
# test_accuracy 0.0949
# Epoch 158
# -------------------------------
# test_accuracy 0.0922
# Epoch 159
# -------------------------------
# test_accuracy 0.0986
# Epoch 160
# -------------------------------
# test_accuracy 0.0952
# Epoch 161
# -------------------------------
# test_accuracy 0.0954
# Epoch 162
# -------------------------------
# test_accuracy 0.0903
# Epoch 163
# -------------------------------
# test_accuracy 0.0944
# Epoch 164
# -------------------------------
# test_accuracy 0.0971
# Epoch 165
# -------------------------------
# test_accuracy 0.0927
# Epoch 166
# -------------------------------
# test_accuracy 0.0928
# Epoch 167
# -------------------------------
# test_accuracy 0.0924
# Epoch 168
# -------------------------------
# test_accuracy 0.0929
# Epoch 169
# -------------------------------
# test_accuracy 0.0943
# Epoch 170
# -------------------------------
# test_accuracy 0.096
# Epoch 171
# -------------------------------
# test_accuracy 0.0916
# Epoch 172
# -------------------------------
# test_accuracy 0.094
# Epoch 173
# -------------------------------
# test_accuracy 0.0943
# Epoch 174
# -------------------------------
# test_accuracy 0.0925
# Epoch 175
# -------------------------------
# test_accuracy 0.0906
# Epoch 176
# -------------------------------
# test_accuracy 0.0933
# Epoch 177
# -------------------------------
# test_accuracy 0.092
# Epoch 178
# -------------------------------
# test_accuracy 0.0903
# Epoch 179
# -------------------------------
# test_accuracy 0.0941
# Epoch 180
# -------------------------------
# test_accuracy 0.0919
# Epoch 181
# -------------------------------
# test_accuracy 0.0931
# Epoch 182
# -------------------------------
# test_accuracy 0.0904
# Epoch 183
# -------------------------------
# test_accuracy 0.0926
# Epoch 184
# -------------------------------
# test_accuracy 0.0924
# Epoch 185
# -------------------------------
# test_accuracy 0.0934
# Epoch 186
# -------------------------------
# test_accuracy 0.0915
# Epoch 187
# -------------------------------
# test_accuracy 0.0904
# Epoch 188
# -------------------------------
# test_accuracy 0.0925
# Epoch 189
# -------------------------------
# test_accuracy 0.0929
# Epoch 190
# -------------------------------
# test_accuracy 0.095
# Epoch 191
# -------------------------------
# test_accuracy 0.0897
# Epoch 192
# -------------------------------
# test_accuracy 0.0906
# Epoch 193
# -------------------------------
# test_accuracy 0.0864
# Epoch 194
# -------------------------------
# test_accuracy 0.0902
# Epoch 195
# -------------------------------
# test_accuracy 0.0939
# Epoch 196
# -------------------------------
# test_accuracy 0.09
# Epoch 197
# -------------------------------
# test_accuracy 0.093
# Epoch 198
# -------------------------------
# test_accuracy 0.0912
# Epoch 199
# -------------------------------
# test_accuracy 0.093
# Epoch 200
# -------------------------------
# test_accuracy 0.0929
# [0.1087, 0.1052, 0.1094, 0.1092, 0.1065, 0.1057, 0.11, 0.1051, 0.1081, 0.1099, 0.1068, 0.1085, 0.1054, 0.1079, 0.1076, 0.1108, 0.1081, 0.1092, 0.1074]
# Epoch 1
# -------------------------------
# test_accuracy 0.0552
# Epoch 2
# -------------------------------
# test_accuracy 0.0879
# Epoch 3
# -------------------------------
# test_accuracy 0.0768
# Epoch 4
# -------------------------------
# test_accuracy 0.0649
# Epoch 5
# -------------------------------
# test_accuracy 0.0794
# Epoch 6
# -------------------------------
# test_accuracy 0.075
# Epoch 7
# -------------------------------
# test_accuracy 0.0829
# Epoch 8
# -------------------------------
# test_accuracy 0.0796
# Epoch 9
# -------------------------------
# test_accuracy 0.0833
# Epoch 10
# -------------------------------
# test_accuracy 0.0834
# Epoch 11
# -------------------------------
# test_accuracy 0.0899
# Epoch 12
# -------------------------------
# test_accuracy 0.0959
# Epoch 13
# -------------------------------
# test_accuracy 0.0901
# Epoch 14
# -------------------------------
# test_accuracy 0.0827
# Epoch 15
# -------------------------------
# test_accuracy 0.091
# Epoch 16
# -------------------------------
# test_accuracy 0.1011
# Epoch 17
# -------------------------------
# test_accuracy 0.0778
# Epoch 18
# -------------------------------
# test_accuracy 0.0908
# Epoch 19
# -------------------------------
# test_accuracy 0.0953
# Epoch 20
# -------------------------------
# test_accuracy 0.104
# Epoch 21
# -------------------------------
# test_accuracy 0.0876
# Epoch 22
# -------------------------------
# test_accuracy 0.0937
# Epoch 23
# -------------------------------
# test_accuracy 0.0912
# Epoch 24
# -------------------------------
# test_accuracy 0.096
# Epoch 25
# -------------------------------
# test_accuracy 0.0924
# Epoch 26
# -------------------------------
# test_accuracy 0.0946
# Epoch 27
# -------------------------------
# test_accuracy 0.1015
# Epoch 28
# -------------------------------
# test_accuracy 0.0857
# Epoch 29
# -------------------------------
# test_accuracy 0.1009
# Epoch 30
# -------------------------------
# test_accuracy 0.0921
# Epoch 31
# -------------------------------
# test_accuracy 0.094
# Epoch 32
# -------------------------------
# test_accuracy 0.0947
# Epoch 33
# -------------------------------
# test_accuracy 0.1066
# Epoch 34
# -------------------------------
# test_accuracy 0.097
# Epoch 35
# -------------------------------
# test_accuracy 0.0962
# Epoch 36
# -------------------------------
# test_accuracy 0.1021
# Epoch 37
# -------------------------------
# test_accuracy 0.1054
# Epoch 38
# -------------------------------
# test_accuracy 0.0975
# Epoch 39
# -------------------------------
# test_accuracy 0.0975
# Epoch 40
# -------------------------------
# test_accuracy 0.0968
# Epoch 41
# -------------------------------
# test_accuracy 0.0935
# Epoch 42
# -------------------------------
# test_accuracy 0.096
# Epoch 43
# -------------------------------
# test_accuracy 0.1037
# Epoch 44
# -------------------------------
# test_accuracy 0.0894
# Epoch 45
# -------------------------------
# test_accuracy 0.1071
# Epoch 46
# -------------------------------
# test_accuracy 0.0984
# Epoch 47
# -------------------------------
# test_accuracy 0.1043
# Epoch 48
# -------------------------------
# test_accuracy 0.1026
# Epoch 49
# -------------------------------
# test_accuracy 0.0953
# Epoch 50
# -------------------------------
# test_accuracy 0.1014
# Epoch 51
# -------------------------------
# test_accuracy 0.0932
# Epoch 52
# -------------------------------
# test_accuracy 0.0938
# Epoch 53
# -------------------------------
# test_accuracy 0.0966
# Epoch 54
# -------------------------------
# test_accuracy 0.0915
# Epoch 55
# -------------------------------
# test_accuracy 0.0949
# Epoch 56
# -------------------------------
# test_accuracy 0.0981
# Epoch 57
# -------------------------------
# test_accuracy 0.1025
# Epoch 58
# -------------------------------
# test_accuracy 0.1089
# Epoch 59
# -------------------------------
# test_accuracy 0.0984
# Epoch 60
# -------------------------------
# test_accuracy 0.0992
# Epoch 61
# -------------------------------
# test_accuracy 0.1025
# Epoch 62
# -------------------------------
# test_accuracy 0.0938
# Epoch 63
# -------------------------------
# test_accuracy 0.1009
# Epoch 64
# -------------------------------
# test_accuracy 0.1022
# Epoch 65
# -------------------------------
# test_accuracy 0.1068
# Epoch 66
# -------------------------------
# test_accuracy 0.0934
# Epoch 67
# -------------------------------
# test_accuracy 0.0949
# Epoch 68
# -------------------------------
# test_accuracy 0.0961
# Epoch 69
# -------------------------------
# test_accuracy 0.0954
# Epoch 70
# -------------------------------
# test_accuracy 0.0938
# Epoch 71
# -------------------------------
# test_accuracy 0.0963
# Epoch 72
# -------------------------------
# test_accuracy 0.0935
# Epoch 73
# -------------------------------
# test_accuracy 0.0978
# Epoch 74
# -------------------------------
# test_accuracy 0.1017
# Epoch 75
# -------------------------------
# test_accuracy 0.099
# Epoch 76
# -------------------------------
# test_accuracy 0.0958
# Epoch 77
# -------------------------------
# test_accuracy 0.0984
# Epoch 78
# -------------------------------
# test_accuracy 0.0932
# Epoch 79
# -------------------------------
# test_accuracy 0.0993
# Epoch 80
# -------------------------------
# test_accuracy 0.0947
# Epoch 81
# -------------------------------
# test_accuracy 0.0993
# Epoch 82
# -------------------------------
# test_accuracy 0.1011
# Epoch 83
# -------------------------------
# test_accuracy 0.097
# Epoch 84
# -------------------------------
# test_accuracy 0.0911
# Epoch 85
# -------------------------------
# test_accuracy 0.1048
# Epoch 86
# -------------------------------
# test_accuracy 0.0976
# Epoch 87
# -------------------------------
# test_accuracy 0.1067
# Epoch 88
# -------------------------------
# test_accuracy 0.0965
# Epoch 89
# -------------------------------
# test_accuracy 0.1044
# Epoch 90
# -------------------------------
# test_accuracy 0.1043
# Epoch 91
# -------------------------------
# test_accuracy 0.1013
# Epoch 92
# -------------------------------
# test_accuracy 0.1009
# Epoch 93
# -------------------------------
# test_accuracy 0.1012
# Epoch 94
# -------------------------------
# test_accuracy 0.0921
# Epoch 95
# -------------------------------
# test_accuracy 0.1004
# Epoch 96
# -------------------------------
# test_accuracy 0.0973
# Epoch 97
# -------------------------------
# test_accuracy 0.1023
# Epoch 98
# -------------------------------
# test_accuracy 0.0965
# Epoch 99
# -------------------------------
# test_accuracy 0.0926
# Epoch 100
# -------------------------------
# test_accuracy 0.1026
# Epoch 101
# -------------------------------
# test_accuracy 0.1022
# Epoch 102
# -------------------------------
# test_accuracy 0.1014
# Epoch 103
# -------------------------------
# test_accuracy 0.0995
# Epoch 104
# -------------------------------
# test_accuracy 0.0934
# Epoch 105
# -------------------------------
# test_accuracy 0.0958
# Epoch 106
# -------------------------------
# test_accuracy 0.0966
# Epoch 107
# -------------------------------
# test_accuracy 0.0985
# Epoch 108
# -------------------------------
# test_accuracy 0.0983
# Epoch 109
# -------------------------------
# test_accuracy 0.0988
# Epoch 110
# -------------------------------
# test_accuracy 0.0998
# Epoch 111
# -------------------------------
# test_accuracy 0.0959
# Epoch 112
# -------------------------------
# test_accuracy 0.1009
# Epoch 113
# -------------------------------
# test_accuracy 0.1
# Epoch 114
# -------------------------------
# test_accuracy 0.1014
# Epoch 115
# -------------------------------
# test_accuracy 0.0973
# Epoch 116
# -------------------------------
# test_accuracy 0.0933
# Epoch 117
# -------------------------------
# test_accuracy 0.0947
# Epoch 118
# -------------------------------
# test_accuracy 0.0929
# Epoch 119
# -------------------------------
# test_accuracy 0.0978
# Epoch 120
# -------------------------------
# test_accuracy 0.0953
# Epoch 121
# -------------------------------
# test_accuracy 0.0927
# Epoch 122
# -------------------------------
# test_accuracy 0.0989
# Epoch 123
# -------------------------------
# test_accuracy 0.1005
# Epoch 124
# -------------------------------
# test_accuracy 0.0962
# Epoch 125
# -------------------------------
# test_accuracy 0.0988
# Epoch 126
# -------------------------------
# test_accuracy 0.0992
# Epoch 127
# -------------------------------
# test_accuracy 0.0973
# Epoch 128
# -------------------------------
# test_accuracy 0.0927
# Epoch 129
# -------------------------------
# test_accuracy 0.0946
# Epoch 130
# -------------------------------
# test_accuracy 0.0951
# Epoch 131
# -------------------------------
# test_accuracy 0.0929
# Epoch 132
# -------------------------------
# test_accuracy 0.0951
# Epoch 133
# -------------------------------
# test_accuracy 0.0945
# Epoch 134
# -------------------------------
# test_accuracy 0.0967
# Epoch 135
# -------------------------------
# test_accuracy 0.0961
# Epoch 136
# -------------------------------
# test_accuracy 0.0963
# Epoch 137
# -------------------------------
# test_accuracy 0.0936
# Epoch 138
# -------------------------------
# test_accuracy 0.092
# Epoch 139
# -------------------------------
# test_accuracy 0.0955
# Epoch 140
# -------------------------------
# test_accuracy 0.0947
# Epoch 141
# -------------------------------
# test_accuracy 0.0942
# Epoch 142
# -------------------------------
# test_accuracy 0.0997
# Epoch 143
# -------------------------------
# test_accuracy 0.0989
# Epoch 144
# -------------------------------
# test_accuracy 0.0928
# Epoch 145
# -------------------------------
# test_accuracy 0.0908
# Epoch 146
# -------------------------------
# test_accuracy 0.0995
# Epoch 147
# -------------------------------
# test_accuracy 0.1003
# Epoch 148
# -------------------------------
# test_accuracy 0.0967
# Epoch 149
# -------------------------------
# test_accuracy 0.0928
# Epoch 150
# -------------------------------
# test_accuracy 0.0937
# Epoch 151
# -------------------------------
# test_accuracy 0.0966
# Epoch 152
# -------------------------------
# test_accuracy 0.0936
# Epoch 153
# -------------------------------
# test_accuracy 0.0985
# Epoch 154
# -------------------------------
# test_accuracy 0.0986
# Epoch 155
# -------------------------------
# test_accuracy 0.0928
# Epoch 156
# -------------------------------
# test_accuracy 0.0951
# Epoch 157
# -------------------------------
# test_accuracy 0.096
# Epoch 158
# -------------------------------
# test_accuracy 0.1006
# Epoch 159
# -------------------------------
# test_accuracy 0.0956
# Epoch 160
# -------------------------------
# test_accuracy 0.0903
# Epoch 161
# -------------------------------
# test_accuracy 0.0918
# Epoch 162
# -------------------------------
# test_accuracy 0.0913
# Epoch 163
# -------------------------------
# test_accuracy 0.0934
# Epoch 164
# -------------------------------
# test_accuracy 0.0954
# Epoch 165
# -------------------------------
# test_accuracy 0.093
# Epoch 166
# -------------------------------
# test_accuracy 0.0892
# Epoch 167
# -------------------------------
# test_accuracy 0.0941
# Epoch 168
# -------------------------------
# test_accuracy 0.0944
# Epoch 169
# -------------------------------
# test_accuracy 0.092
# Epoch 170
# -------------------------------
# test_accuracy 0.0901
# Epoch 171
# -------------------------------
# test_accuracy 0.0938
# Epoch 172
# -------------------------------
# test_accuracy 0.0915
# Epoch 173
# -------------------------------
# test_accuracy 0.093
# Epoch 174
# -------------------------------
# test_accuracy 0.093
# Epoch 175
# -------------------------------
# test_accuracy 0.0905
# Epoch 176
# -------------------------------
# test_accuracy 0.0941
# Epoch 177
# -------------------------------
# test_accuracy 0.0936
# Epoch 178
# -------------------------------
# test_accuracy 0.0961
# Epoch 179
# -------------------------------
# test_accuracy 0.0912
# Epoch 180
# -------------------------------
# test_accuracy 0.0909
# Epoch 181
# -------------------------------
# test_accuracy 0.0963
# Epoch 182
# -------------------------------
# test_accuracy 0.0935
# Epoch 183
# -------------------------------
# test_accuracy 0.0877
# Epoch 184
# -------------------------------
# test_accuracy 0.0937
# Epoch 185
# -------------------------------
# test_accuracy 0.0947
# Epoch 186
# -------------------------------
# test_accuracy 0.0936
# Epoch 187
# -------------------------------
# test_accuracy 0.0921
# Epoch 188
# -------------------------------
# test_accuracy 0.089
# Epoch 189
# -------------------------------
# test_accuracy 0.0913
# Epoch 190
# -------------------------------
# test_accuracy 0.0933
# Epoch 191
# -------------------------------
# test_accuracy 0.0929
# Epoch 192
# -------------------------------
# test_accuracy 0.0939
# Epoch 193
# -------------------------------
# test_accuracy 0.0936
# Epoch 194
# -------------------------------
# test_accuracy 0.0897
# Epoch 195
# -------------------------------
# test_accuracy 0.0918
# Epoch 196
# -------------------------------
# test_accuracy 0.0879
# Epoch 197
# -------------------------------
# test_accuracy 0.094
# Epoch 198
# -------------------------------
# test_accuracy 0.0932
# Epoch 199
# -------------------------------
# test_accuracy 0.0913
# Epoch 200
# -------------------------------
# test_accuracy 0.0918
# [0.1087, 0.1052, 0.1094, 0.1092, 0.1065, 0.1057, 0.11, 0.1051, 0.1081, 0.1099, 0.1068, 0.1085, 0.1054, 0.1079, 0.1076, 0.1108, 0.1081, 0.1092, 0.1074, 0.1089]
# Done!
# [0.1087, 0.1052, 0.1094, 0.1092, 0.1065, 0.1057, 0.11, 0.1051, 0.1081, 0.1099, 0.1068, 0.1085, 0.1054, 0.1079, 0.1076, 0.1108, 0.1081, 0.1092, 0.1074, 0.1089]
